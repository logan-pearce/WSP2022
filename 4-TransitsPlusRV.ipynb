# %% [markdown]
# <font color='cornflowerblue' size = 7>Combining RV and Transits to learn even more!</font>
#
# <font color='cornflowerblue'>**Discuss:**</font>
#  - What can we learn about a planet from its transit signal?  What can't we learn from transits alone?
#  - What can we learn about a planet from its RV signal?  What can't we learn from the RV alone?
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <font color='cornflowerblue'>**Discuss:**</font>
# What did we decide we needed to learn about a planet to see if we could call it "Earth-like"?<br>
# How could we use RV and transits together to start to measure some of those things?
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# Check out this plot, what does it tell you about these confirmed exoplanets?
#
# <img src="http://www.loganpearcescience.com/wsp/exoplanets_density1.png" alt="density1" style="width: 800px;"/><br>
# <sup> Image source: https://www.open.edu/openlearn/mod/oucontent/view.php?id=74851&section=7</sup>

# %% [markdown]
#  - What do think Kepler-11b is like?<br>
#  - CoRoT-7b?<br>
#  - Kepler-10b?<br>
#  - Kepler-11d?<br>
#  <br>
#
#  Here is another one, check out Figure 3: [https://www.researchgate.net/publication/234054739_A_Detailed_Model_Grid_for_Solid_Planets_from_01_through_100_EarthMasses](https://www.researchgate.net/publication/234054739_A_Detailed_Model_Grid_for_Solid_Planets_from_01_through_100_EarthMasses)
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ____
# <font color='cornflowerblue' size = 7>Density is key!</font><br><br>
# What is density?  What is the equation?
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# Ok, so what do we need to measure for a planet to estimate its density?  How can we do that?
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <font color='cornflowerblue'> But wait!</font> don't we only get *minimum mass* from RV?  What does the fact that a planet transits tell us about the inclination of the orbit?

# %% [markdown]
# <font color='cornflowerblue' size = 5>Your turn!</font><br><br>
# 1. Go to the Exoplanet Archive and search for GJ-1214 b, one of the planets on the above plot.  <br>
# There is a radial velocity curve in the ancillary information, use that to estimate the mass (is it the minimum mass? Why or why not?).<br>
# There is not a light curve available on the archive, so we need to dig into the literature to find one.  If you look at the "Planetary Parameters" for this planet, you'll see many journal articles that have measured parameters for this planet.  Click on some of the references and look inside to see if you can find a light curve you can use to estimate the radius.  You can see the article by clicking on one the "Full Text Sources" options.
# <img src="http://www.loganpearcescience.com/wsp/ads.png" alt="ads" style="width: 800px;"/><br>
# <font color='cornflowerblue'>Pro Tip!</font> You may see several light curves taken at many different wavelengths.  This is done to try to estimate the planet's atmosphere, because different atmospheric compositions have different transit depths at different wavelenghts.  One option could be to compute a radius for several of the light curves and take an average.
#
# Compute the density to GJ-1214 b and compare it to the plot and literature values.  What do you think this planet is likely composed of??
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# 2. Pick another planet on that plot, find it in the Exoplanet Archive, and compute its density.
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>

# %% [markdown]
# _______
# But wait, on the plot from Figure 3 of Zeng and Sassalov, Earth and Venus are really close together.  But we know that Venus is not habitable!  What ELSE is different between Earth and Venus?
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# ________

# %% [markdown]
# <font color='cornflowerblue' size = 7>Temperature makes a BIG difference!</font><br><br>

# %% [markdown]
# Look at CoRoT-7 b on the above density plot.  It says "Mercury-like".  Mercury's surface temperature is ~700K (~800F) at the hottest, while CoRoT-7 b's surface is almost 2000K (~3000F)!  Do some googling: what is different between Mercury and CoRoT-7b that might explain this huge difference??<br>
# <font color='cornflowerblue'>Hints:</font> You can find info about CoRoT-7 and CoRoT-7 b on the Exoplanet Archive; the key is related to stuff we've been talking about this week!

# %% [markdown]
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>

# %% [markdown]
# Two major factors influence the equilibrium temperature of a planet: the temperature of the host star and the planet's distance from it.<br>
# Let's derive an equation. (Let's ignore atmospheres to keep it simple)
#
# <img src="http://www.loganpearcescience.com/wsp/EqTemp_Page_1.jpg" alt="ads" style="width: 800px;"/><br>
# <img src="http://www.loganpearcescience.com/wsp/EqTemp_Page_2.jpg" alt="ads" style="width: 800px;"/><br>
# <img src="http://www.loganpearcescience.com/wsp/EqTemp_Page_3.jpg" alt="ads" style="width: 800px;"/><br>

# %% [markdown]
# <font color='cornflowerblue' size = 5>Your turn!</font><br><br>
# What is the equilibrium temperature of KELT-9b? Use the Exoplanet archive to find all the relevant information to compute the surface temperature in Kelvin.  What is this temperature in Fahrenheit? How do you feel about this planet????
