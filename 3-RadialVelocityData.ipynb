# %% [markdown]
# <font color='cornflowerblue' size = 7>Detecting Exoplanets through Radial Velocity</font>
#
# <font color='cornflowerblue'>**Discuss:**</font> What was the RV method again?  What can we learn about an exoplanet through an RV detection?  Go [here](https://exoplanets.nasa.gov/alien-worlds/ways-to-find-a-planet/#) if you need a refresher.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <font color='cornflowerblue'>**Discuss:**</font>
#  - Wait, what is a "spectrum" anyway??  Do some googling and discuss with your peers, and come up with a definition for a stellar spectrum.
#  - Go [here](https://noirlab.edu/public/images/noao-sun/#:~:text=Each%20of%20the%2050%20slices,type%20K1%20(or%20K2)) .  Tell me what you see.
#  - Check out [this article](https://www.researchgate.net/publication/248851913_Improving_Earth-like_planets%27_detection_with_an_ELT_The_differential_radial_velocity_experiment) from the Astronomy and Astrophysics Journal.  Look at Figure 1.  What is this figure showing?  What are the similaries and differences between the spectra of the different types of stars?
#  - What does stellar spectra have to do with detecting planets through the radial velocity method?
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <img src="http://www.loganpearcescience.com/wsp/rvdoodle.png" alt="51pegrv" style="width: 800px;"/><br>
# <sup> Image source: https://www.planetary.org/articles/color-shifting-stars-the-radial-velocity-method</sup>
#
# Here is the kind of data astronomers use to detect planets through the radial velocity method.  In fact, this is the RV curve of one of the very first confirmed exoplanets, 51 Pegasi b, by Michel Mayor and Didier Queloz in [1995](https://www.nature.com/articles/378355a0).  In fact they won the [Nobel Prize in 2019](https://www.nobelprize.org/prizes/physics/2019/summary/) for this discovery!
#
# Here is the plot from their discovery paper, made by observing 51 Peg over 18 months with a very high precision spectrograph.  It shows the velocity along the line of sight (towards and away from the observer, called the radial velocity) on the y-axis, and phase (indicated by the greek letter Phi) on the x-axis.  Phase is just a number quantifying how far along an orbit the planet is at any given time, and it ranges from 0 to 1.  So phase=0.5 would be halfway through the orbit, phase=0.25 is one quarter, etc.
#
# <img src="http://www.loganpearcescience.com/wsp/51peg-rv.jpeg" alt="51pegrv" style="width: 800px;"/>
# <br><br>
# Here is another plot of 51 Peg, this time with days on the x-axis:<br><br>
# <img src="http://www.loganpearcescience.com/wsp/51peg-rv2.gif" alt="51pegrv2" style="width: 800px;"/>
#
#
#
# <font color='cornflowerblue'>**Discuss:**</font> What do you notice about the line-of-sight velocity of the star 51 Peg over time?  What does this plot tell you about the planet 51 Peg b?  <font color='cornflowerblue'>*Hint: What might the height of the peaks and separation between them tell you?*</font>
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### Let's simulate some exoplanet RVs!
# Let's take a look at an exoplanet radial velocity simulator that you can find [here](https://astro.unl.edu/classaction/animations/extrasolarplanets/radialvelocitysimulator.html).  Answer the following questions:
#
# 1. What changes in the RV curve plot when you vary the:<br>
#     a. Plaent Mass?<br>
#     b. Inclination?<br>
#     c. Semi-major axis?<br>
#     d. Eccentricity?<br>
#     e. Star Mass?<br>
#
# 2. Click the "show simulated measurements" box and play around with the noise and number of measurements.  What happens to the simulated observation?  What does this tell you about the kinds of observations we need to make of transiting planets?
#
# 3. Under "presets" pick a few transit signals of real transiting exoplanets and observe the light curve.  What do you notice?
#
#
# 4. Now check out [this RV simulator](http://www.bu.edu/astronomy/visualizations/AlienWorlds/simulation-radial.html).  What happens to the signal when you change the planet's radius?
#
# <br/><br/>
# <br/><br/>
# <br/><br/>
# <br/><br/>
# <br/><br/>
# <br/><br/>
# <br/><br/>
# <br/><br/>

# %% [markdown]
# ___
# <font color='cornflowerblue' size = 7>Analyzing RV curves</font><br><br>
# <font color='cornflowerblue' size=5> Orbital period and semi-major axis</font>
#
# Determining the separation from the star (semi-major axis) with RV signals is very similar to transits!  It's Kepler's third law again.
#
#
# Reminder, the equation for Kepler's 3rd law is:<br>
# $$P^2  = \frac{4 \pi^2 a^3}{G M_*}$$
#
# where $G$ is the gravitational constant, $M_*$ is the mass of the star, and $a$ is the semi-major axis of the planet.
#
#
#
#
# <br/><br/>
# We can solve this equation for the semimajor axis.
#
# If we use the units $M_\odot$, AU, and years, $G\approx 4\pi^2$, and so it cancels out and leaves us with:
# $a=(M_* P^2)^{\frac{1}{3}}$<br>
#
# #### Always pay attention to units!
# <br/>
# <img src="http://www.loganpearcescience.com/wsp/18delb.jpg" alt="18delb" style="width: 800px;"/>
#
# #### What is the semi-major axis of 18 Delphini b?
# 18 Del is much more massive than our own sun, its mass is $M_* = 2.35 M_\odot$

# %%
# Period in days:
P = 
# Star's mass:
M_star = 
# Conversion from days to years:
days_in_a_year = 
# Convert period from days to years:
P_in_years = 

# Compute semi-major axis:
a_planet =     #write equation here

print(a_planet)

# %% [markdown]
# Check your work: https://en.wikipedia.org/wiki/18_Delphini_b

# %% [markdown]
# <font color='cornflowerblue' size=5>Planet mass</font>
#
# As you saw with the planet simulator, unlike transits we can't learn anything about the planet's radius from the RV curve!  But also unlike transits, the MASS of the planet does affect the strength of the signal.
#
# <font color='cornflowerblue'>**Discuss:**</font> Why?
# <br><br>
# <br><br><br><br><br><br><br><br>
# <br><br><br><br><br><br><br><br><br><br>
# <br><br><br><br><br><br><br><br><br><br>
# <br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# Did you guess seesaws?
# <br><br>
# <img src="http://www.loganpearcescience.com/wsp/seesaw.jpeg" alt="seesaw1" style="width: 600px;"/>
#
# Two people on either end of the seesaw exert a force on the beam, which pivots at the fulcrum.  The distance from the fulcrum and the person's mass determines how much force they put on the beam.  In this above pic, the child and the man balance because the child with less mass is farther from the fulcrum than the man with more mass, so they exert the same force on the beam and it balances.
#
# <br><br>
# <img src="http://www.loganpearcescience.com/wsp/seesaw2.jpeg" alt="seesaw2" style="width: 600px;"/>
# <br><br>
# If the child and an apple are both the same distance away, they don't balance because the apple exerts so much less force at that distance than the child.
#
# <br><br><br>
# It is the same with planets and stars!  The planet and star both orbit their common center of mass, which acts like a fulcrum.  If the planet is more massive it exerts more force on the star and vice versa.  Also if the planet is closer to the star it exerts more force and vice versa!
#
# <img src="http://www.loganpearcescience.com/wsp/rv_compare_a.png" alt="seesaw2" style="width: 600px;"/><br>
# <sup>Image source: http://spiff.rit.edu/classes/resceu/lectures/radial_vel/radial_vel_2.html</sup>

# %% [markdown]
# ## Computing planet mass from RV signals:
# The physics of computing the mass via RV is the same as the seesaw actually.  The equation is given by Newton's law of gravitation:
#
# $$F_g = G \frac{M_* M_p}{r^2}$$
#
# Where $M_*$ and $M_p$ are mass of star and planet, $G$ is the gravitational constant (same as above), and $r$ is the semi-major axis determined from the period, and $F_g$ is the force of gravity between star and planet.
#
# To get the force of gravity, we need to use Newton's second law of motion:
# $$ F_g = ma$$
# where $m$ is mass (in this case it would be the total mass $m$ = $M_*$ + $M_p$) and $a$ is acceleration.  Acceleration is defined as change in velocity over time:
# $$ a = \frac{v_2 - v_1}{t_2 - t_1}$$
#
# <font color='cornflowerblue'>**Your turn:**</font> Put these equations together, simplify, and solve for $M_p$ to get the equation for getting planet mass out of RV signals.
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
#
# <font color='cornflowerblue'>**Your turn:**</font> What is the mass of 18 Del b?  Use the semi-major axis we found above.
#
# <img src="http://www.loganpearcescience.com/wsp/18delb.jpg" alt="18delb" style="width: 800px;"/>
#
# ### ALWAYS pay attention to units!
#
# <font color='cornflowerblue'>*Hints:*</font>
#
# 1 AU = $1.5\times10^{11}$ m<br>
# 1 year = $3.15\times10^{7}$ s<br>
# 1 $M_\odot$ = $2\times10^{30}$ kg<br>
# 1 $M_{jup}$ = $2\times10^{27}$ kg<br>

# %%
# Do your math here!

# semi-major axis from above in AU = a_planet
# Conversion from AU to meters:
m_in_au = 
# Convert sma to m:
a_planet_m = 

# velocities from graph:
v1 = 
v2 = 
t1 = 
t2 = 
# change in time from v1 to v2:
delta_t = 
# conversion from years to sec:
sec_in_year = 
delta_t_years = 

# acceleration:
accel = 

# Star's mass in solar masses = M_star
# Conversion from solar masses to kg:
M_star_kg = 

# Gravitational constant in m^3/(kg * s^2):
Gconst = 

#Write equation here:
M_planet =



print(M_planet)

# %% [markdown]
# When done do some googling to see if you're right!

# %% [markdown]
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
#
# <br><br>
# <br><br>

# %% [markdown]
# # But not so fast! There's a problem.
#
# Check out these two simulated RV signals from that simulator.  Look at what is different between them, and the resulting RV signal strength.<br><br>
# <img src="http://www.loganpearcescience.com/wsp/rv-mass-inc-degen1.jpg" alt="rvdegen1" style="width: 800px;"/>
# <img src="http://www.loganpearcescience.com/wsp/rv-mass-inc-degen2.jpg" alt="rvdegen2" style="width: 800px;"/>
# <br>

# %% [markdown]
# Do you see the problem?
# <br><br>
#
# <img src="http://www.loganpearcescience.com/wsp/two_orbits_a.png" alt="twoorbits" style="width: 800px;"/><br>
# <sup>Image source: http://spiff.rit.edu/classes/resceu/lectures/radial_vel/radial_vel_2.html</sup>

# %% [markdown]
# There is no way to know the inclination of the orbit from the RV signal alone.  The RV signal is the velocity projected along our line of sight only, but the planet has velocity in three dimensions.  So the mass we determine from an RV signal alone is only a <font color='cornflowerblue'> **Minimum Mass**</font>!
#
# True mass: $$m_p = \frac{m_{rv}}{sin(i)} $$
#
# So RV masses are usually reported as $M_p$ sin(i)
#
# <font color='cornflowerblue'>Math refresher!  What is sine?</font>

# %% [markdown]
# ___
# <font color='cornflowerblue' size=7>Let's dig into data!</font>

# %% [markdown]
# Go to the [Exoplanet Archive](https://exoplanetarchive.ipac.caltech.edu/) and search HD 100777 (in the "Explore the Archive" box).  Open the "Ancillary Information" and click on the plot symbol next to the "Radial Velocity Curve"<br>
# <img src="http://www.loganpearcescience.com/wsp/rv-hd100777-1.png" alt="hd100777-1" style="width: 600px;"/><br>

# %% [markdown]
# What is the minimum mass and semi-major axis of HD 100777 b?  Pay attention to units and axis scales! (remember BJD is Barycntric Julian Days, and 1 BJD = 1 day).<br>
#
# When you have an answer check against the reported planet paramters to see how you did!
